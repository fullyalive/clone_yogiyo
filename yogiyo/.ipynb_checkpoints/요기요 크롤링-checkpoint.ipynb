# %%
import os
import json
import requests # pip install requests
import random
import time
from django.core.files.base import ContentFile
from shop.models import Category, Shop, Item
from urllib.parse import urljoin
from fake_useragent import UserAgent # pip install fake-useragent

# %%
class Yogiyo:
    HOST = 'https://www.yogiyo.co.kr'
    
    def __init__(self, headers):
        self.headers = headers
        
    def get_restaurant_list_by_geo(self, zip_code):
        url = self.HOST + '/api/v1/restaurants-geo/'
        params = dict(
            items=20,
            order='rank',
            page=0,
            search='',
            zip_code=zip_code,
        )
        res = requests.get(url, params=params, headers=self.headers)
        return res.json()
    
    def get_menu_list(self, restaurant_id): # restaurant_id를 지정해주면 그 레스토랑의 메뉴를 가지고 오겠다
        base_url = self.HOST + '/api/v1/restaurants/{restaurant_id}/menu/?add_photo_menu=original'
        url = base_url.format(restaurant_id=restaurant_id)
        res = requests.get(url, headers=self.headers)
        return res.json()

# %%
## 활용 : 식당등록

# %%
user_agent = UserAgent()

# %%
headers = {
    'X-ApiKey': 'iphoneap',
    'X-ApiSecret': 'fe5183cc3dea12bd0ce299cf110a75a2',
    'X-MOD-SBB-CTYPE': 'xhr',
    'User-Agent': user_agent.Chrome,
}

yogiyo = Yogiyo(headers)

# %%
zip_code = '143201'
restaurants = yogiyo.get_restaurant_list_by_geo('143201')['restaurants']
restaurants
# Out:
# [{'rating': 200039.783495783,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 69,
#   'phone_downlisted': False,
#   'franchise_name': '(주)롯데지알에스 / 롯데리아',
#   'review_image_count': 96,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352594304',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['치킨', '야식', '피자양식', '프랜차이즈', '1인분주문'],
#   'min_order_amount': 10000,
#   'distance': 1.3448337975624016,
#   'logo_url': '/media/restaurant_logos/롯데리아_20160408_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': True,
#   'name': '롯데리아-건대역점',
#   'section_pos': 1,
#   'owner_reply_count': 0,
#   'one_dish': 1,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:00 - 09:59',
#   'keywords': '롯데리아-건대역점 세트 핫크리스피버거세트 디저트 치즈스틱 디저트 양념감자 세트 불고기버거세트 디저트 포테이토 치킨 화이어윙2조각 버거 데리버거 디저트 해쉬브라운 버거 불고기버거 치킨 화이어윙4조각',
#   'new_rating': 1.1775082069550717,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0714389,
#   'list_pos': 1,
#   'id': 234937,
#   'can_review': 0,
#   'estimated_delivery_time': '55~65분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 794,
#   'relay_methods': ['email', 'box_helicom'],
#   'section': 'contract',
#   'loyal_score': 21.1618741616888,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 화양동 4-20',
#   'lat': 37.5407068,
#   'end': '09:59:00',
#   'slug': '롯데리아-건대역점',
#   'review_avg': 4.31863979848866,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['online'],
#   'takeout': False},
#  {'rating': 200033.134541859,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15600원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 198,
#   'sms_bonus': True,
#   'franchise_id': 45,
#   'phone_downlisted': False,
#   'franchise_name': '(주)케이프렌즈 / 강정구의피자생각',
#   'review_image_count': 61,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712920855',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['프랜차이즈', '야식', '피자양식'],
#   'min_order_amount': 15600,
#   'distance': 1.9750517162795314,
#   'logo_url': '/media/restaurant_logos/강정구의피자생각_20171127_Franchise이미지약정서_crop_200x200_udmoYf7.jpg',
#   'except_cash': False,
#   'name': '강정구의피자생각-광진점',
#   'section_pos': 2,
#   'owner_reply_count': 198,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:30 - 04:00',
#   'keywords': '강정구의피자생각-광진점 스페셜세트메뉴 치즈크러스트세트1（치즈크러스트피자L1판＋치즈오븐스파게티＋콜라1.25L） 음료 코카콜라1.25L 스페셜세트메뉴 오리지널세트1（오리지널피자L1판＋치즈오븐스파게티＋콜라1.25L） 시카고피자메뉴 베이컨시카고피자 소스&기타메뉴 갈릭디핑소스2개 사이드메뉴 마약스파게티 음료 스프라이트1.25L 사이드메뉴 치즈오븐스파게티 사이드메뉴 버팔로윙（10개） 음료 코카콜라500mL',
#   'new_rating': 0.7794068640983258,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0758847565,
#   'list_pos': 2,
#   'id': 260194,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 200,
#   'relay_methods': ['email', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 14.3604301838558,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:30:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 군자동 48-49 비아트리체빌딩 1층',
#   'lat': 37.5564630424343,
#   'end': '04:00:00',
#   'slug': '강정구의피자생각-광진점TLAY26',
#   'review_avg': 4.445,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200030.880591534,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 1000원, 최소 주문 금액 14000원',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 306,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 156,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 1000,
#   'additional_discount_pickup': 0,
#   'phone': '050352596371',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '치킨'],
#   'min_order_amount': 14000,
#   'distance': 2.4236408695803258,
#   'logo_url': '/media/restaurant_logos/바베큐양념치킨02_20131128_FoodAD_crop_200x200_kJNbZEp.jpg',
#   'except_cash': False,
#   'name': '불스바베큐-중곡점',
#   'section_pos': 3,
#   'owner_reply_count': 306,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '18:00 - 04:00',
#   'keywords': '불스바베큐-중곡점 음료메뉴 코카콜라1.25L 사이드메뉴 불스감자튀김R 바베큐메뉴 불스숯불양념바베큐 음료메뉴 스프라이트1.5L 주류 생맥주1000cc 음료메뉴 코카콜라500mL 바베큐메뉴 불스숯불바베큐（반）＋불스숯불양념（반） 사이드메뉴 새우튀김10조각 주류 생맥주2000cc 추가메뉴 공기밥',
#   'new_rating': 0.5763788567794829,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.083354534793,
#   'list_pos': 3,
#   'id': 236616,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 471,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 11.5276757673887,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '18:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 39-1 1층',
#   'lat': 37.5625387132301,
#   'end': '04:00:00',
#   'slug': '불스바베큐-중곡점',
#   'review_avg': 4.54564755838641,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200022.164275854,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 20000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2018-09-14T04:29:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 138,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 64,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352565735',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '족발보쌈'],
#   'min_order_amount': 20000,
#   'distance': 2.3806857176892207,
#   'logo_url': '/media/restaurant_logos/족발샐러드01_20131128_FoodAD_crop_200x200_3.jpg',
#   'except_cash': False,
#   'name': '팔당왕족발',
#   'section_pos': 4,
#   'owner_reply_count': 138,
#   'one_dish': 0,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '16:30 - 04:30',
#   'keywords': '팔당왕족발 족발메뉴 족발小（2人）국내산앞발 사이드메뉴 공기밥 족발메뉴 반반족발中（족발＋매운양념족발） 보쌈메뉴 보쌈小（2人）국내산목살,삼겹살 족발메뉴 족발中（2~3人）국내산앞발 족발메뉴 족발大（3~4人）국내산앞발 사이드메뉴 콜라1.25L 보쌈메뉴 보쌈中（2~3人）국내산목살,삼겹살 보쌈메뉴 보쌈大（3~4人）국내산목살,삼겹살 족발메뉴 매운양념족발中（2~3人）국내산앞발',
#   'new_rating': 0.26239719338165635,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0824028,
#   'list_pos': 4,
#   'id': 39231,
#   'can_review': 0,
#   'estimated_delivery_time': '35~45분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 224,
#   'relay_methods': ['email', 'box_helicom'],
#   'section': 'contract',
#   'loyal_score': 3.46335842298751,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '16:30:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 광진구 중곡동 41-20',
#   'lat': 37.5620419,
#   'end': '04:30:00',
#   'slug': '팔당왕족발',
#   'review_avg': 4.39732142857143,
#   'discount_from': '2018-09-13T19:45:00',
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200031.846497145,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 13000원 이상',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 67,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352566597',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '한식'],
#   'min_order_amount': 13000,
#   'distance': 3.223499179509366,
#   'logo_url': '/media/restaurant_logos/부대찌개01_20131128_FoodAD_crop_200x200_12.jpg',
#   'except_cash': False,
#   'name': '서울맛집-광진구',
#   'section_pos': 5,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '09:00 - 05:40',
#   'keywords': '서울맛집-광진구 SetA메뉴 SetA-1（부대전골＋계란찜or누룽지＋공기2） SetA메뉴 SetA-2（돼지목살김치전골＋계란찜or누룽지＋공기2） 사이드메뉴 공기밥 SetB메뉴 SetB-1（닭볶음탕＋계란찜or누룽지＋공기3） SetA메뉴 SetA-4（제육볶음＋계란찜or누룽지＋공기2） 음료 콜라1.25L SetA메뉴 SetA-6（오삼불고기＋계란찜or누룽지＋공기2） 음료 사이다1.25L 음료 콜라500mL SetA메뉴 SetA-7（낙지볶음＋계란찜or누룽지＋공기2）',
#   'new_rating': 0.540767102286496,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0832546,
#   'list_pos': 5,
#   'id': 34018,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 592,
#   'relay_methods': ['email', 'box_helicom'],
#   'section': 'contract',
#   'loyal_score': 13.5191775571624,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '09:00:00',
#   'description': '',
#   'tags': ['excellent'],
#   'address': '서울 광진구 중곡동 199-3',
#   'lat': 37.5697647999421,
#   'end': '05:40:00',
#   'slug': '서울맛집-광진구',
#   'review_avg': 4.09797297297297,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200030.135437609,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 18,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712905972',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['한식', '야식'],
#   'min_order_amount': 15000,
#   'distance': 3.229957520656522,
#   'logo_url': '/media/restaurant_logos/불고기01_20131203_foodon_crop_200x200_SGN87NI.jpg',
#   'except_cash': False,
#   'name': '남원석쇠불고기-본점',
#   'section_pos': 6,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '09:00 - 05:40',
#   'keywords': '남원석쇠불고기-본점 간장석쇠불고기메뉴 간장석쇠불고기小 사이드메뉴 공기밥 사이드메뉴 계란찜 덮밥／볶음밥류 제육덮밥 찜／찌개／국류 차돌된장찌개 찜／찌개／국류 김치찌개 찜／찌개／국류 순대국 덮밥／볶음밥류 김치스팸볶음밥 매운석쇠불고기메뉴 매운석쇠불고기小 사이드메뉴 스팸구이',
#   'new_rating': 0.53857186678,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0832945,
#   'list_pos': 6,
#   'id': 245801,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 150,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 13.4642966695,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '09:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 199-3 1층',
#   'lat': 37.5698261,
#   'end': '05:40:00',
#   'slug': '남원석쇠불고기-본점',
#   'review_avg': 4.34,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200031.641209438,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 311,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352566381',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['한식', '야식'],
#   'min_order_amount': 15000,
#   'distance': 3.223499179509366,
#   'logo_url': '/media/restaurant_logos/불닭01_20120524_FoodAD_crop_200x200_55.jpg',
#   'except_cash': False,
#   'name': '직화신불닭',
#   'section_pos': 7,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '09:00 - 05:40',
#   'keywords': '직화신불닭 반반세트 반반세트2가지선택 종합세트 종합세트小 기본메뉴 무뼈닭발 사이드메뉴 주먹밥 기본메뉴 순살불닭 사이드메뉴 스팸주먹밥 음료 쿨피스930mL 사이드메뉴 날치알주먹밥 음료 콜라1.5L 사이드메뉴 계란찜',
#   'new_rating': 0.527911511781836,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0832546,
#   'list_pos': 7,
#   'id': 25981,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 2262,
#   'relay_methods': ['email', 'box_helicom'],
#   'section': 'contract',
#   'loyal_score': 13.1977877945459,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '09:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 화양동 34-43',
#   'lat': 37.5697647999421,
#   'end': '05:40:00',
#   'slug': '직화신불닭',
#   'review_avg': 4.18523430592396,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200024.627380982,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 3000원, 최소 주문 금액 14000원',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 7,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 3,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 3000,
#   'additional_discount_pickup': 0,
#   'phone': '050712936906',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['한식', '야식'],
#   'min_order_amount': 14000,
#   'distance': 2.4525518954621717,
#   'logo_url': '/media/restaurant_logos/물냉면06_20131128_FoodAD_crop_200x200_3yatInV.jpg',
#   'except_cash': False,
#   'name': '평양불냉면&시골고기냉면',
#   'section_pos': 8,
#   'owner_reply_count': 7,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 05:30',
#   'keywords': '평양불냉면&시골고기냉면 메인메뉴 물냉면 메인메뉴 비빔냉면 메인메뉴 사계절왕만두세트（왕만두4개＋갈비만두6개） 추가메뉴 갈비만두6개 메인메뉴 명품보쌈비빔냉면 추가메뉴 냉면사리추가 메인메뉴 명품족발비빔냉면 메인메뉴 열무（물）냉면 메인메뉴 불비빔냉면 추가메뉴 냉면육수추가',
#   'new_rating': 0.4465848601904581,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.081179919846,
#   'list_pos': 8,
#   'id': 275634,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 19,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 8.42738098207231,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 242-6',
#   'lat': 37.5625228047583,
#   'end': '05:30:00',
#   'slug': '평양불냉면_명품고기냉면',
#   'review_avg': 4.05263157894737,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200022.471469252,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 45,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352548732',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['한식', '야식'],
#   'min_order_amount': 15000,
#   'distance': 3.223499179509366,
#   'logo_url': '/media/restaurant_logos/감자탕01_20131128_FoodAD_crop_200x200_4.jpg',
#   'except_cash': False,
#   'name': '24시뼈다귀해장국',
#   'section_pos': 9,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '09:00 - 05:40',
#   'keywords': '24시뼈다귀해장국 뼈다귀해장국메뉴 뼈다귀해장국（1人） 사이드메뉴 공기밥 묵은지김치찜메뉴 묵은지생갈비김치찜 묵은지김치찜메뉴 묵은지뼈다귀김치찜 사이드메뉴 콜라1.25L 뼈찜메뉴 뼈찜小 사이드메뉴 사이다1.25L 사이드메뉴 콜라500mL 사이드메뉴 사이다500mL 묵은지김치찜메뉴 묵은지고등어김치찜',
#   'new_rating': 0.25022073327566047,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0832546,
#   'list_pos': 9,
#   'id': 34017,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 495,
#   'relay_methods': ['email', 'box_helicom'],
#   'section': 'contract',
#   'loyal_score': 6.25551833189151,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '09:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 199-3',
#   'lat': 37.5697647999421,
#   'end': '05:40:00',
#   'slug': '24시뼈다귀해장국',
#   'review_avg': 4.01010101010101,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200012.025162846,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 25000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': True,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 4,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712940230',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '족발보쌈'],
#   'min_order_amount': 25000,
#   'distance': 1.4383050526588566,
#   'logo_url': '/media/restaurant_logos/족발야시장-건대입구역점_20180626_가맹로고이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '족발야시장-건대입구역점',
#   'section_pos': 10,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '15:00 - 04:00',
#   'keywords': '족발야시장-건대입구역점 세트메뉴 반반족발세트（족발반＋직화불족발반） 메인메뉴 족발小 메인메뉴 보쌈小 메인메뉴 직화불족발中 사이드메뉴 날치알주먹밥（6알） 세트메뉴 족발보쌈세트中 메인메뉴 족발中 주류 참이슬클래식 면메뉴 쟁반막국수 메인메뉴 냉채족발中',
#   'new_rating': 0.23334550331088744,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.070381870597,
#   'list_pos': 10,
#   'id': 279182,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 2,
#   'relay_methods': ['email', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': -1.97483715393353,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '15:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 화양동 5-75',
#   'lat': 37.5412294617557,
#   'end': '04:00:00',
#   'slug': '족발야시장-건대입구역점',
#   'review_avg': 5.0,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200019.933969715,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 1000원, 최소 주문 금액 16000원',
#   'is_available_delivery': True,
#   'threshold': 5000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 23,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 17,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 1000,
#   'additional_discount_pickup': 0,
#   'phone': '050352596367',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '중식'],
#   'min_order_amount': 16000,
#   'distance': 2.4236408695803258,
#   'logo_url': '/media/restaurant_logos/탕수육06_20131128_FoodAD_crop_200x200_nRRY6VB.jpg',
#   'except_cash': False,
#   'name': '수안심탕수육-중곡점',
#   'section_pos': 11,
#   'owner_reply_count': 23,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '18:00 - 04:00',
#   'keywords': '수안심탕수육-중곡점 추가메뉴 코카콜라1.25L 탕수육메뉴 수안심탕수육小 사이드메뉴 양념감자튀김（R） 추가메뉴 스프라이트1.5L 사이드메뉴 조각고구마튀김（R） 사이드메뉴 생새우튀김10조각 사이드메뉴 닭날개봉튀김（8조각） 추가메뉴 스프라이트500mL 추가메뉴 코카콜라500mL 주류 참이슬후레쉬',
#   'new_rating': 0.18098149189552123,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.083354534793,
#   'list_pos': 11,
#   'id': 236615,
#   'can_review': 0,
#   'estimated_delivery_time': '35~45분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 59,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 1.64274164528966,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '18:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 39-1 1층',
#   'lat': 37.5625387132301,
#   'end': '04:00:00',
#   'slug': '수안심탕수육-중곡점',
#   'review_avg': 4.10169491525424,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200005.670500428,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 18000원 이상',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 2,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712926611',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['야식', '한식'],
#   'min_order_amount': 18000,
#   'distance': 2.252814276412658,
#   'logo_url': '/media/restaurant_logos/천호동똥찌비-20180108_가맹로고이미지약정서_crop_200x200_IYVGOua.jpg',
#   'except_cash': False,
#   'name': '천호동똥찌비',
#   'section_pos': 12,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '16:00 - 05:00',
#   'keywords': '천호동똥찌비 메인메뉴 똥집통마늘구이 사이드메뉴 돼지껍데기（1인분） 밥메뉴 날치알주먹밥 메인메뉴 똥반오반통마늘구이 추가메뉴 떡추가 메인메뉴 모듬통마늘구이 사이드메뉴 계란찜 사이드메뉴 그냥계란말이 밥메뉴 공기밥 사이드메뉴 치즈계란말이',
#   'new_rating': 0.11348793105862237,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.074293787123,
#   'list_pos': 12,
#   'id': 265748,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 14,
#   'relay_methods': ['email', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': -0.89873034147115,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '16:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 군자동 466-2 1층',
#   'lat': 37.5586200846739,
#   'end': '05:00:00',
#   'slug': '천호동똥찌비',
#   'review_avg': 4.71428571428571,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200011.562654992,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 21,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352559979',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '치킨'],
#   'min_order_amount': 15000,
#   'distance': 3.3353656432121297,
#   'logo_url': '/media/restaurant_logos/후라이드03_20120524_FoodAD_crop_200x200_236.jpg',
#   'except_cash': False,
#   'name': '위대한치킨(24시)',
#   'section_pos': 13,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:00 - 09:59',
#   'keywords': '위대한치킨(24시) 치킨메뉴 순살치킨 치킨메뉴 후라이드치킨 치킨메뉴 양념치킨 음료 콜라1.25L 치킨메뉴 핫후라이드 음료 콜라500ml 음료 사이다1.25L 음료 사이다500ml 치킨메뉴 치킨뱅이 치킨메뉴 골뱅이무침',
#   'new_rating': 0.09777190014854241,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0835126,
#   'list_pos': 13,
#   'id': 20524,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 215,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 2.44429750371356,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:00:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 광진구 중곡동 555-4 우리들한의원 1층',
#   'lat': 37.5707930999422,
#   'end': '09:59:00',
#   'slug': '위대한치킨(24시)',
#   'review_avg': 3.72558139534884,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200016.229130451,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 12000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 12,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 11,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352556046',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['치킨', '야식'],
#   'min_order_amount': 12000,
#   'distance': 1.994257142157625,
#   'logo_url': '/media/restaurant_logos/반반01_20120524_FoodAD_crop_200x200_150.jpg',
#   'except_cash': False,
#   'name': '투인순살두마리치킨',
#   'section_pos': 14,
#   'owner_reply_count': 12,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '06:00 - 05:59',
#   'keywords': '투인순살두마리치킨 치킨두마리메뉴（6가지맛중에선택） 두마리선택 사이드메뉴 콜라1.25L 사이드메뉴 사이다1.25L 사이드메뉴 콜라500mL 사이드메뉴 사이다500mL 사이드메뉴 캔사이다 사이드메뉴 캔콜라',
#   'new_rating': 0.07277625207927532,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.071968379635,
#   'list_pos': 14,
#   'id': 19669,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 111,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 8.65255387463184,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '06:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 군자동 117-41 지하1층',
#   'lat': 37.5545204277033,
#   'end': '05:59:00',
#   'slug': '투인순살두마리치킨',
#   'review_avg': 2.57657657657658,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200003.523365008,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#   'is_available_delivery': True,
#   'threshold': 5000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 70,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712902510',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['중식'],
#   'min_order_amount': 10000,
#   'distance': 0.6442960798299869,
#   'logo_url': '/media/restaurant_logos/짜장면01_20131128_FoodAD_crop_200x200_251.jpg',
#   'except_cash': False,
#   'name': '복만루',
#   'section_pos': 15,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '09:00 - 08:59',
#   'keywords': '복만루 면류 짜장면 세트메뉴 세트1（탕수육＋짜장2） 면류 짬뽕 요리부 탕수육 면류 쟁반짜장 면류 간짜장 반반메뉴 탕볶밥 반반메뉴 탕짜면 반반메뉴 탕짬면 밥류 볶음밥',
#   'new_rating': 0.0674447537087185,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.081757482187,
#   'list_pos': 15,
#   'id': 2963,
#   'can_review': 0,
#   'estimated_delivery_time': '30~40분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 458,
#   'relay_methods': ['email', 'box_helicom'],
#   'section': 'contract',
#   'loyal_score': -10.0924007581321,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '09:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 자양동 219-12 이화빌라 1층',
#   'lat': 37.536628186382,
#   'end': '08:59:00',
#   'slug': '복만루',
#   'review_avg': 4.29912663755459,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200015.237232067,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 1000원, 최소 주문 금액 14000원',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 1,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 4,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 1000,
#   'additional_discount_pickup': 0,
#   'phone': '050352596341',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '치킨'],
#   'min_order_amount': 14000,
#   'distance': 2.4236408695803258,
#   'logo_url': '/media/restaurant_logos/후라이드치킨02_20131128_FoodAD_crop_200x200_Qn5nlFu.jpg',
#   'except_cash': False,
#   'name': '옛날시장통닭-중곡점',
#   'section_pos': 16,
#   'owner_reply_count': 1,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '18:00 - 04:00',
#   'keywords': '옛날시장통닭-중곡점 옛날통닭메뉴 옛날후라이드 사이드메뉴 코카콜라1.25L 주류 생맥주1000cc 옛날통닭메뉴 옛날후라이드（반）＋옛날양념후라이드（반） 사이드메뉴 스프라이트1.5L 옛날통닭메뉴 옛날순살후라이드（반）＋옛날양념순살후라이드（반） 사이드메뉴 코카콜라500mL 옛날통닭메뉴 옛날시장통닭 주류 생맥주2000cc 옛날통닭메뉴 버팔로윙16조각',
#   'new_rating': 0.0649429269615504,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.083354534793,
#   'list_pos': 16,
#   'id': 236458,
#   'can_review': 0,
#   'estimated_delivery_time': '35~45분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 22,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': -1.25822247805961,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '18:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 39-1 1층',
#   'lat': 37.5625387132301,
#   'end': '04:00:00',
#   'slug': '옛날시장통닭-중곡점',
#   'review_avg': 4.22727272727273,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200017.760241348,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 30000원',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': True,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 13,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050712912816',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '족발보쌈'],
#   'min_order_amount': 30000,
#   'distance': 3.497059885190369,
#   'logo_url': '/media/restaurant_logos/족발04_20131128_FoodAD_crop_200x200_eHYPQHV.jpg',
#   'except_cash': False,
#   'name': '가장맛있는족발-장안사거리점',
#   'section_pos': 17,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '14:00 - 05:00',
#   'keywords': '가장맛있는족발-장안사거리점 메뉴 반반족발（족발＋불족） 메뉴 족발 메뉴 보쌈 메뉴 가족의족발보쌈 사이드메뉴 콜라500mL 메뉴 직화불족발 메뉴 큰쟁반국수 사이드메뉴 사이다500mL 메뉴 냉채족발大 메뉴 해물부추전',
#   'new_rating': 0.0607322345502372,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.070337864772,
#   'list_pos': 17,
#   'id': 252392,
#   'can_review': 0,
#   'estimated_delivery_time': '40~50분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 32,
#   'relay_methods': ['email', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 1.51830586375593,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '14:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 동대문구 장안동 365-1 1층',
#   'lat': 37.5695572355026,
#   'end': '05:00:00',
#   'slug': '가장맛있는족발-장안사거리점',
#   'review_avg': 3.9375,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200015.446990792,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 3000원, 최소 주문 금액 23000원',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 89,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 51,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 3000,
#   'additional_discount_pickup': 0,
#   'phone': '050352560433',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['치킨', '야식', '프랜차이즈'],
#   'min_order_amount': 23000,
#   'distance': 2.4525518954621717,
#   'logo_url': '/media/restaurant_logos/바베큐치킨02_20131128_FoodAD_crop_200x200_ax1DuYB.jpg',
#   'except_cash': False,
#   'name': '구어스치킨-전철역점',
#   'section_pos': 18,
#   'owner_reply_count': 89,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 05:30',
#   'keywords': '구어스치킨-전철역점 구어스두마리메뉴 세트3（참숯바베큐＋구어스치킨） 사이드메뉴 코카콜라1.25L 구어스한마리메뉴 구어스치킨 구어스한마리메뉴 참숯바베큐 구어스한마리메뉴 국내산순살구어스 구어스한마리메뉴 마늘간장구어스치킨 구어스두마리메뉴 세트5（마늘간장구어스＋구어스치킨） 사이드메뉴 공기밥 구어스두마리메뉴 세트6（양념구어스＋구어스치킨） 사이드메뉴 사이다1.5L',
#   'new_rating': 0.059160721785181274,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.081179919846,
#   'list_pos': 18,
#   'id': 32323,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 214,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': -1.25822247805961,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 242-6',
#   'lat': 37.5625228047583,
#   'end': '05:30:00',
#   'slug': '구어스치킨-중곡점',
#   'review_avg': 4.37383177570093,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200010.035370486,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 4000원, 최소 주문 금액 30000원',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 41,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 40,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 3000,
#   'additional_discount_pickup': 0,
#   'phone': '050352594427',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['일식돈까스', '한식', '야식'],
#   'min_order_amount': 25000,
#   'distance': 2.4525518954621717,
#   'logo_url': '/media/restaurant_logos/홍어삼합01_20131205_foodon_crop_200x200_YeaT9eP.jpg',
#   'except_cash': False,
#   'name': '영산포홍어삼합',
#   'section_pos': 19,
#   'owner_reply_count': 41,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 05:30',
#   'keywords': '영산포홍어삼합 기본메뉴 홍어삼합中 기본메뉴 홍어삼합大 사이드메뉴 햇반 주류 참이슬후레쉬 주류 처음처럼 주류 장수막걸리 사이드메뉴 콜라1.25L 사이드메뉴 쟁반막국수 기본메뉴 홍어삼합특大 기본메뉴 홍어무침（500g）',
#   'new_rating': 0.05348508549675567,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.081179919846,
#   'list_pos': 19,
#   'id': 235054,
#   'can_review': 0,
#   'estimated_delivery_time': '45~55분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 125,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': -1.40011338527025,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 242-6',
#   'lat': 37.5625228047583,
#   'end': '05:30:00',
#   'slug': '영산포홍어삼합RO3N5J',
#   'review_avg': 4.6,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200013.247341447,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 20000원',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': True,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 7,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050352409749',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '일식돈까스'],
#   'min_order_amount': 20000,
#   'distance': 2.589758464529851,
#   'logo_url': '/media/restaurant_logos/회08_20131205_foodon_crop_200x200_kUT8dkE.jpg',
#   'except_cash': False,
#   'name': '청정활어회직판장',
#   'section_pos': 20,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '16:00 - 05:00',
#   'keywords': '청정활어회직판장 활어회메뉴 광어＋연어 초밥메뉴 회덮밥 초밥메뉴 초밥1인분（10pcs） 활어회메뉴 연어회 초밥메뉴 연어초밥1인분（10pcs） 활어회메뉴 광어 기타메뉴 매운탕 활어회메뉴 광어＋우럭＋연어 활어회메뉴 광어＋우럭 세꼬시메뉴 광어세꼬시',
#   'new_rating': 0.033480426498245806,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.079477550767,
#   'list_pos': 20,
#   'id': 140345,
#   'can_review': 0,
#   'estimated_delivery_time': '50~60분',
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 22,
#   'relay_methods': ['email', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': -1.2141970148946,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '16:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 240-5 건화빌딩 1층',
#   'lat': 37.5634808365351,
#   'end': '05:00:00',
#   'slug': '청정활어회직판장',
#   'review_avg': 4.5,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'foodfly_restaurant_id': None,
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False}]

# %%
for rest in restaurants:
    category_name = rest['categories'][0]
    print(category_name)
    category = Category.objects.get(name=category_name) # 요기요는 M:N 관계 => 지정 name의 Category가 없다면, Category.DoesNotExist 예외 발생
    latlng = '{lat}, {lng}'.format(**rest)
    logo_url = urljoin(Yogiyo.HOST, rest['logo_url'])
    shop = Shop(category=category, name=rest['name'], latlng=latlng, meta=rest)
    logo_name = os.path.basename(logo_url)
    logo_data = requests.get(logo_url).content
    shop.photo.save(logo_name, ContentFile(logo_data), save=False)
    print('{name}: {lat}, {lng}, {categories}, {logo_url}'.format(**rest))
    
    shop.save()
# Out:
# 치킨
# 롯데리아-건대역점: 37.5407068, 127.0714389, ['치킨', '야식', '피자양식', '프랜차이즈', '1인분주문'], /media/restaurant_logos/롯데리아_20160408_Franchise이미지약정서_crop_200x200.jpg
# 프랜차이즈
# 강정구의피자생각-광진점: 37.5564630424343, 127.0758847565, ['프랜차이즈', '야식', '피자양식'], /media/restaurant_logos/강정구의피자생각_20171127_Franchise이미지약정서_crop_200x200_udmoYf7.jpg
# 야식
# 불스바베큐-중곡점: 37.5625387132301, 127.083354534793, ['야식', '치킨'], /media/restaurant_logos/바베큐양념치킨02_20131128_FoodAD_crop_200x200_kJNbZEp.jpg
# 야식
# 팔당왕족발: 37.5620419, 127.0824028, ['야식', '족발보쌈'], /media/restaurant_logos/족발샐러드01_20131128_FoodAD_crop_200x200_3.jpg
# 야식
# 서울맛집-광진구: 37.5697647999421, 127.0832546, ['야식', '한식'], /media/restaurant_logos/부대찌개01_20131128_FoodAD_crop_200x200_12.jpg
# 한식
# 남원석쇠불고기-본점: 37.5698261, 127.0832945, ['한식', '야식'], /media/restaurant_logos/불고기01_20131203_foodon_crop_200x200_SGN87NI.jpg
# 한식
# 직화신불닭: 37.5697647999421, 127.0832546, ['한식', '야식'], /media/restaurant_logos/불닭01_20120524_FoodAD_crop_200x200_55.jpg
# 한식
# 평양불냉면&시골고기냉면: 37.5625228047583, 127.081179919846, ['한식', '야식'], /media/restaurant_logos/물냉면06_20131128_FoodAD_crop_200x200_3yatInV.jpg
# 한식
# 24시뼈다귀해장국: 37.5697647999421, 127.0832546, ['한식', '야식'], /media/restaurant_logos/감자탕01_20131128_FoodAD_crop_200x200_4.jpg
# 야식
# 족발야시장-건대입구역점: 37.5412294617557, 127.070381870597, ['야식', '족발보쌈'], /media/restaurant_logos/족발야시장-건대입구역점_20180626_가맹로고이미지약정서_crop_200x200.jpg
# 야식
# 수안심탕수육-중곡점: 37.5625387132301, 127.083354534793, ['야식', '중식'], /media/restaurant_logos/탕수육06_20131128_FoodAD_crop_200x200_nRRY6VB.jpg
# 야식
# 천호동똥찌비: 37.5586200846739, 127.074293787123, ['야식', '한식'], /media/restaurant_logos/천호동똥찌비-20180108_가맹로고이미지약정서_crop_200x200_IYVGOua.jpg
# 야식
# 위대한치킨(24시): 37.5707930999422, 127.0835126, ['야식', '치킨'], /media/restaurant_logos/후라이드03_20120524_FoodAD_crop_200x200_236.jpg
# 치킨
# 투인순살두마리치킨: 37.5545204277033, 127.071968379635, ['치킨', '야식'], /media/restaurant_logos/반반01_20120524_FoodAD_crop_200x200_150.jpg
# 중식
# 복만루: 37.536628186382, 127.081757482187, ['중식'], /media/restaurant_logos/짜장면01_20131128_FoodAD_crop_200x200_251.jpg
# 야식
# 옛날시장통닭-중곡점: 37.5625387132301, 127.083354534793, ['야식', '치킨'], /media/restaurant_logos/후라이드치킨02_20131128_FoodAD_crop_200x200_Qn5nlFu.jpg
# 야식
# 가장맛있는족발-장안사거리점: 37.5695572355026, 127.070337864772, ['야식', '족발보쌈'], /media/restaurant_logos/족발04_20131128_FoodAD_crop_200x200_eHYPQHV.jpg
# 치킨
# 구어스치킨-전철역점: 37.5625228047583, 127.081179919846, ['치킨', '야식', '프랜차이즈'], /media/restaurant_logos/바베큐치킨02_20131128_FoodAD_crop_200x200_ax1DuYB.jpg
# 일식돈까스
# 영산포홍어삼합: 37.5625228047583, 127.081179919846, ['일식돈까스', '한식', '야식'], /media/restaurant_logos/홍어삼합01_20131205_foodon_crop_200x200_YeaT9eP.jpg
# 야식
# 청정활어회직판장: 37.5634808365351, 127.079477550767, ['야식', '일식돈까스'], /media/restaurant_logos/회08_20131205_foodon_crop_200x200_kUT8dkE.jpg

# %%
for shop in Shop.objects.all():
    print(shop.name, shop.latlng)
# Out:
# 맥시칸치킨-연희점 37.5628544, 126.9307123
# 멕시카나-신촌점 37.5547722235414, 126.941644837675
# 원할머니보쌈-신촌점 37.5574104353704, 126.935986925105
# 디디치킨-연세대점 37.5661219586013, 126.931808950602
# 냉면앤고기어때 37.5747968607615, 126.922656131739
# 가화만사성24시 37.55706, 126.9361078
# 네네치킨-이대역점 37.5570037, 126.9414717
# 공룡치킨-신촌점 37.5538226251049, 126.93177389498
# 네네치킨-연희점 37.5659973, 126.930478
# 혼밥혼술-신촌점 37.5556092705005, 126.940414980044
# 범벅치킨-신촌점 37.5578773, 126.9346843
# 홍푸드스테이크시리즈 37.5526264, 126.93543
# 네네치킨-북가좌2점 37.580757208118, 126.915095502055
# 유자유김치떡볶이-신촌점 37.5590514418098, 126.935642820668
# 닭꾸버-서울1호신촌점 37.5573034385236, 126.932320878454
# 명품임실치즈피자-신촌점 37.5563502089596, 126.943191206591
# 노랑통닭-명지대점 37.5787759999432, 126.9239699
# 지브로통삼겹살전문점 37.5747968607615, 126.922656131739
# 굽네치킨-서대문연희점 37.5732125, 126.9353151
# 직화신불닭-강북 37.5817391, 126.9356768
# 롯데리아-건대역점 37.5407068, 127.0714389
# 강정구의피자생각-광진점 37.5564630424343, 127.0758847565
# 버거킹-건대화양점(24) 37.5409386584498, 127.068494238588
# 팔당왕족발 37.5620419, 127.0824028
# 불스바베큐-중곡점 37.5625387132301, 127.083354534793
# 서울맛집-광진구 37.5697647999421, 127.0832546
# 남원석쇠불고기-본점 37.5698261, 127.0832945
# 직화신불닭 37.5697647999421, 127.0832546
# 평양불냉면&시골고기냉면 37.5625228047583, 127.081179919846
# 24시뼈다귀해장국 37.5697647999421, 127.0832546
# 족발야시장-건대입구역점 37.5412294617557, 127.070381870597
# 수안심탕수육-중곡점 37.5625387132301, 127.083354534793
# 천호동똥찌비 37.5586200846739, 127.074293787123
# 위대한치킨(24시) 37.5707930999422, 127.0835126
# 투인순살두마리치킨 37.5545204277033, 127.071968379635
# 롯데리아-건대역점 37.5407068, 127.0714389
# 강정구의피자생각-광진점 37.5564630424343, 127.0758847565
# 버거킹-건대화양점(24) 37.5409386584498, 127.068494238588
# 팔당왕족발 37.5620419, 127.0824028
# 불스바베큐-중곡점 37.5625387132301, 127.083354534793
# 서울맛집-광진구 37.5697647999421, 127.0832546
# 남원석쇠불고기-본점 37.5698261, 127.0832945
# 직화신불닭 37.5697647999421, 127.0832546
# 평양불냉면&시골고기냉면 37.5625228047583, 127.081179919846
# 24시뼈다귀해장국 37.5697647999421, 127.0832546
# 족발야시장-건대입구역점 37.5412294617557, 127.070381870597
# 수안심탕수육-중곡점 37.5625387132301, 127.083354534793
# 천호동똥찌비 37.5586200846739, 127.074293787123
# 위대한치킨(24시) 37.5707930999422, 127.0835126
# 투인순살두마리치킨 37.5545204277033, 127.071968379635
# 롯데리아-건대역점 37.5407068, 127.0714389
# 강정구의피자생각-광진점 37.5564630424343, 127.0758847565
# 버거킹-건대화양점(24) 37.5409386584498, 127.068494238588
# 팔당왕족발 37.5620419, 127.0824028
# 불스바베큐-중곡점 37.5625387132301, 127.083354534793
# 서울맛집-광진구 37.5697647999421, 127.0832546
# 남원석쇠불고기-본점 37.5698261, 127.0832945
# 직화신불닭 37.5697647999421, 127.0832546
# 평양불냉면&시골고기냉면 37.5625228047583, 127.081179919846
# 24시뼈다귀해장국 37.5697647999421, 127.0832546
# 족발야시장-건대입구역점 37.5412294617557, 127.070381870597
# 수안심탕수육-중곡점 37.5625387132301, 127.083354534793
# 천호동똥찌비 37.5586200846739, 127.074293787123
# 위대한치킨(24시) 37.5707930999422, 127.0835126
# 투인순살두마리치킨 37.5545204277033, 127.071968379635
# 복만루 37.536628186382, 127.081757482187
# 옛날시장통닭-중곡점 37.5625387132301, 127.083354534793
# 가장맛있는족발-장안사거리점 37.5695572355026, 127.070337864772
# 구어스치킨-전철역점 37.5625228047583, 127.081179919846
# 영산포홍어삼합 37.5625228047583, 127.081179919846
# 롯데리아-건대역점 37.5407068, 127.0714389
# 강정구의피자생각-광진점 37.5564630424343, 127.0758847565
# 불스바베큐-중곡점 37.5625387132301, 127.083354534793
# 팔당왕족발 37.5620419, 127.0824028
# 서울맛집-광진구 37.5697647999421, 127.0832546
# 남원석쇠불고기-본점 37.5698261, 127.0832945
# 직화신불닭 37.5697647999421, 127.0832546
# 평양불냉면&시골고기냉면 37.5625228047583, 127.081179919846
# 24시뼈다귀해장국 37.5697647999421, 127.0832546
# 족발야시장-건대입구역점 37.5412294617557, 127.070381870597
# 수안심탕수육-중곡점 37.5625387132301, 127.083354534793
# 천호동똥찌비 37.5586200846739, 127.074293787123
# 위대한치킨(24시) 37.5707930999422, 127.0835126
# 투인순살두마리치킨 37.5545204277033, 127.071968379635
# 복만루 37.536628186382, 127.081757482187
# 옛날시장통닭-중곡점 37.5625387132301, 127.083354534793
# 가장맛있는족발-장안사거리점 37.5695572355026, 127.070337864772
# 구어스치킨-전철역점 37.5625228047583, 127.081179919846
# 영산포홍어삼합 37.5625228047583, 127.081179919846
# 청정활어회직판장 37.5634808365351, 127.079477550767

# %%
for shop in Shop.objects.all():
    restaurant_id = shop.meta['id']
    menu_list = yogiyo.get_menu_list(restaurant_id)
    print(shop.name)
    for sub_menu_list in menu_list:
        items = sub_menu_list['items']
        for item_meta in items:
            item = Item(shop=shop, name=item_meta['name'], amount=item_meta['price'])
            
            item_image_url = item_meta.get('image', '') # iamge가 없는 메뉴도 있음
            if item_image_url:
                item_image_url = urljoin(Yogiyo.HOST, item_meta['image'])
                
                item_image_name = os.path.basename(item_image_url)
                item_image_data = requests.get(item_image_url).content
                item.photo.save(item_image_name, ContentFile(item_image_data), save=False)
                
            print('saving item: {}'.format(item.name))
            item.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-e252423aa5f6> in <module>()
#       1 for shop in Shop.objects.all():
#       2     restaurant_id = shop.meta['id']
# ----> 3     menu_list = yogiyo.get_menu_list(restaurant_id)
#       4     print(shop.name)
#       5     for sub_menu_list in menu_list:
#
# <ipython-input-34-425a5d188f1c> in get_menu_list(self, restaurant_id)
#      20         base_url = self.HOST + '/api/v1/restaurants/{restaurant_id}/menu/?add_photo_menu=android'
#      21         url = base_url.format(restaurant_id=restaurant_id)
# ---> 22         res = reguests.get(url, headers=self.headers)
#      23         return res.json()
#
# NameError: name 'reguests' is not defined
